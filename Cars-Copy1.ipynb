# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\menna\Downloads\cars price prediction\car_price_prediction.csv.zip")
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
#//////////////data exploration///////

# %%
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
#/////////////////cleaning////////////

# %%
df.duplicated().sum()
# Out:
# 313

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (18924, 18)

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.Levy.replace({'-':'0'},inplace=True)
df['Levy']=df['Levy'].astype(int)
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                  int32
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
df['Mileage']=df['Mileage'].str.replace('km','')
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df['Engine volume'].unique()
# Out:
# array(['3.5', '3', '1.3', '2.5', '2', '1.8', '2.4', '4', '1.6', '3.3',
#        '2.0 Turbo', '2.2 Turbo', '4.7', '1.5', '4.4', '3.0 Turbo',
#        '1.4 Turbo', '3.6', '2.3', '1.5 Turbo', '1.6 Turbo', '2.2',
#        '2.3 Turbo', '1.4', '5.5', '2.8 Turbo', '3.2', '3.8', '4.6', '1.2',
#        '5', '1.7', '2.9', '0.5', '1.8 Turbo', '2.4 Turbo', '3.5 Turbo',
#        '1.9', '2.7', '4.8', '5.3', '0.4', '2.8', '3.2 Turbo', '1.1',
#        '2.1', '0.7', '5.4', '1.3 Turbo', '3.7', '1', '2.5 Turbo', '2.6',
#        '1.9 Turbo', '4.4 Turbo', '4.7 Turbo', '0.8', '0.2 Turbo', '5.7',
#        '4.8 Turbo', '4.6 Turbo', '6.7', '6.2', '1.2 Turbo', '3.4',
#        '1.7 Turbo', '6.3 Turbo', '2.7 Turbo', '4.3', '4.2', '2.9 Turbo',
#        '0', '4.0 Turbo', '20', '3.6 Turbo', '0.3', '3.7 Turbo', '5.9',
#        '5.5 Turbo', '0.2', '2.1 Turbo', '5.6', '6', '0.7 Turbo',
#        '0.6 Turbo', '6.8', '4.5', '0.6', '7.3', '0.1', '1.0 Turbo', '6.3',
# ...

# %%
df['Engine volume']=df['Engine volume'].str.replace('Turbo','')
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df['Engine volume']=df['Engine volume'].astype(float)
df['Mileage']=df['Mileage'].astype(int)
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                  int32
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume       float64
# Mileage               int32
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
import datetime
dtime=datetime.datetime.now()
dtime
# Out:
# datetime.datetime(2025, 7, 14, 2, 48, 18, 78635)

# %%
df['Age']=dtime.year-df['Prod. year']
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     0        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type  Engine volume  Mileage  Cylinders Gear box type  \
# 0              Yes    Hybrid            3.5   186005        6.0     Automatic
# 1               No    Petrol            3.0   192000        6.0     Tiptronic
# 2               No    Petrol            1.3   200000        4.0      Variator
# 3              Yes    Hybrid            2.5   168966        4.0     Automatic
# 4              Yes    Petrol            1.3    91901        4.0     Automatic
#
#   Drive wheels   Doors             Wheel   Color  Airbags  Age
# ...

# %%
df.drop(['Prod. year'],axis=1,inplace = True)

# %%
df.drop(['ID','Doors'],axis=1,inplace = True)

# %%
df.head(10)
# Out:
#    Price  Levy Manufacturer     Model   Category Leather interior Fuel type  \
# 0  13328  1399        LEXUS    RX 450       Jeep              Yes    Hybrid
# 1  16621  1018    CHEVROLET   Equinox       Jeep               No    Petrol
# 2   8467     0        HONDA       FIT  Hatchback               No    Petrol
# 3   3607   862         FORD    Escape       Jeep              Yes    Hybrid
# 4  11726   446        HONDA       FIT  Hatchback              Yes    Petrol
# 5  39493   891      HYUNDAI  Santa FE       Jeep              Yes    Diesel
# 6   1803   761       TOYOTA     Prius  Hatchback              Yes    Hybrid
# 7    549   751      HYUNDAI    Sonata      Sedan              Yes    Petrol
# 8   1098   394       TOYOTA     Camry      Sedan              Yes    Hybrid
# 9  26657     0        LEXUS    RX 350       Jeep              Yes    Petrol
#
#    Engine volume  Mileage  Cylinders Gear box type Drive wheels  \
# 0            3.5   186005        6.0     Automatic          4x4
# ...

# %%
#//////////////visualization /////////

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=15,figsize=(15,10))
plt.show()

# %%
top10 = df['Manufacturer'].value_counts().sort_values(ascending=False)[:10]
top10
# Out:
# Manufacturer
# HYUNDAI          3729
# TOYOTA           3606
# MERCEDES-BENZ    2043
# FORD             1088
# CHEVROLET        1047
# BMW              1036
# HONDA             960
# LEXUS             927
# NISSAN            645
# VOLKSWAGEN        571
# Name: count, dtype: int64

# %%
top10.plot(figsize=(10,4))
plt.show()

# %%
meanprices=[df[df['Manufacturer'] == i]['Price'].mean() for i in list(top10.index)]
meanprices
# Out:
# [22306.00080450523,
#  14302.447864669994,
#  18590.331375428294,
#  15411.85018382353,
#  14894.873925501433,
#  20609.468146718147,
#  14162.073958333332,
#  20052.594390507013,
#  9835.84031007752,
#  11471.77408056042]

# %%
plt.plot(top10.index,meanprices)
plt.show()

# %%
import seaborn as sns

# %%
corr = df.select_dtypes(include=['number']).corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr,linewidth='0.5',annot=True,fmt='.3f')
plt.show()

# %%
object1 = df.select_dtypes(include='object')
object1.head()
# Out:
#   Manufacturer    Model   Category Leather interior Fuel type Gear box type  \
# 0        LEXUS   RX 450       Jeep              Yes    Hybrid     Automatic
# 1    CHEVROLET  Equinox       Jeep               No    Petrol     Tiptronic
# 2        HONDA      FIT  Hatchback               No    Petrol      Variator
# 3         FORD   Escape       Jeep              Yes    Hybrid     Automatic
# 4        HONDA      FIT  Hatchback              Yes    Petrol     Automatic
#
#   Drive wheels             Wheel   Color
# 0          4x4        Left wheel  Silver
# 1          4x4        Left wheel   Black
# 2        Front  Right-hand drive   Black
# 3          4x4        Left wheel   White
# 4        Front        Left wheel  Silver

# %%
object1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18924 entries, 0 to 19236
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      18924 non-null  object
#  1   Model             18924 non-null  object
#  2   Category          18924 non-null  object
#  3   Leather interior  18924 non-null  object
#  4   Fuel type         18924 non-null  object
#  5   Gear box type     18924 non-null  object
#  6   Drive wheels      18924 non-null  object
#  7   Wheel             18924 non-null  object
#  8   Color             18924 non-null  object
# dtypes: object(9)
# memory usage: 1.4+ MB

# %%
for col in object1:
    plt.figure(figsize=(15,5))
    c10=df[col].value_counts()[:10]
    colors=['black','purple','pink','yellow']
    c10.plot(kind='bar',color=colors)
    plt.title('c10'+" "+col)
    plt.show()

# %%
#//////////////////////////outlier//////////////////////////////

# %%
df.describe()
# Out:
#               Price          Levy  Engine volume       Mileage     Cylinders  \
# count  1.892400e+04  18924.000000   18924.000000  1.892400e+04  18924.000000
# mean   1.858744e+04    632.886493       2.306251  1.555373e+06      4.580216
# std    1.921356e+05    568.273736       0.877591  4.880221e+07      1.200223
# min    1.000000e+00      0.000000       0.000000  0.000000e+00      1.000000
# 25%    5.331000e+03      0.000000       1.800000  7.019575e+04      4.000000
# 50%    1.317200e+04    642.000000       2.000000  1.264000e+05      4.000000
# 75%    2.206300e+04    917.000000       2.500000  1.891198e+05      4.000000
# max    2.630750e+07  11714.000000      20.000000  2.147484e+09     16.000000
#
#             Airbags           Age
# count  18924.000000  18924.000000
# mean       6.568379     14.085764
# std        4.322323      5.665749
# min        0.000000      5.000000
# 25%        4.000000     10.000000
# 50%        6.000000     13.000000
# ...

# %%
sns.boxplot(df['Age'])
plt.show()

# %%
sns.boxplot(df['Levy'])
plt.show()

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Levy'] = df['Levy'].fillna(df['Levy'].median())

# %% [raw]
# df_numeric=df.select_dtypes(exclude='object')
# for col in df_numeric:
#     q1=df[col].quantile(0.25)
#     q3=df[col].quantile(0.75)
#     iqr=q3-q1
#     low=q1-1.5*iqr
#     high=q3+1.5*iqr
#     outlier=((df_numeric[col]>high)|(df_numeric[col]<low)).sum()
#     total=df_numeric[col].shape[0]
#     print(f"Total Oultiers in {col} are :{outlier}-{round((outlier)*100/total,2)}%")
#     if outlier>0:
#       df=df.loc[(df[col]<=high) & (df[col]>=low)]

# %%
# ////////////////////////transform data///////////////////////////

# %%
df_object=df.select_dtypes(include='object')
df_numeric=df.select_dtypes(exclude='object')

# %%
df_object
# Out:
#         Manufacturer    Model   Category Leather interior Fuel type  \
# 0              LEXUS   RX 450       Jeep              Yes    Hybrid
# 1          CHEVROLET  Equinox       Jeep               No    Petrol
# 2              HONDA      FIT  Hatchback               No    Petrol
# 3               FORD   Escape       Jeep              Yes    Hybrid
# 4              HONDA      FIT  Hatchback              Yes    Petrol
# ...              ...      ...        ...              ...       ...
# 19232  MERCEDES-BENZ  CLK 200      Coupe              Yes       CNG
# 19233        HYUNDAI   Sonata      Sedan              Yes    Petrol
# 19234        HYUNDAI   Tucson       Jeep              Yes    Diesel
# 19235      CHEVROLET  Captiva       Jeep              Yes    Diesel
# 19236        HYUNDAI   Sonata      Sedan              Yes    Hybrid
#
#       Gear box type Drive wheels             Wheel   Color
# 0         Automatic          4x4        Left wheel  Silver
# ...

# %%
df_numeric
# Out:
#        Price  Levy  Engine volume  Mileage  Cylinders  Airbags  Age
# 0      13328  1399            3.5   186005        6.0       12   15
# 1      16621  1018            3.0   192000        6.0        8   14
# 2       8467     0            1.3   200000        4.0        2   19
# 3       3607   862            2.5   168966        4.0        0   14
# 4      11726   446            1.3    91901        4.0        4   11
# ...      ...   ...            ...      ...        ...      ...  ...
# 19232   8467     0            2.0   300000        4.0        5   26
# 19233  15681   831            2.4   161600        4.0        8   14
# 19234  26108   836            2.0   116365        4.0        4   15
# 19235   5331  1288            2.0    51258        4.0        4   18
# 19236    470   753            2.4   186923        4.0       12   13
#
# [18924 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
for col in range(0,df_object.shape[1]):
    df_object.iloc[:,col]=la.fit_transform( df_object.iloc[:,col])

# %%
df_object=df_object.astype(int)

# %%
df_object.dtypes
# Out:
# Manufacturer        int32
# Model               int32
# Category            int32
# Leather interior    int32
# Fuel type           int32
# Gear box type       int32
# Drive wheels        int32
# Wheel               int32
# Color               int32
# dtype: object

# %%
df=pd.concat([df_object,df_numeric],axis=1)

# %%
df
# Out:
#        Manufacturer  Model  Category  Leather interior  Fuel type  \
# 0                32   1242         4                 1          2
# 1                 8    658         4                 0          5
# 2                21    684         3                 0          5
# 3                16    661         4                 1          2
# 4                21    684         3                 1          5
# ...             ...    ...       ...               ...        ...
# 19232            36    385         1                 1          0
# 19233            23   1334         9                 1          5
# 19234            23   1442         4                 1          1
# 19235             8    456         4                 1          1
# 19236            23   1334         9                 1          2
#
#        Gear box type  Drive wheels  Wheel  Color  Price  Levy  Engine volume  \
# 0                  0             0      0     12  13328  1399            3.5
# ...

# %%
df.dtypes
# Out:
# Manufacturer          int32
# Model                 int32
# Category              int32
# Leather interior      int32
# Fuel type             int32
# Gear box type         int32
# Drive wheels          int32
# Wheel                 int32
# Color                 int32
# Price                 int64
# Levy                  int32
# Engine volume       float64
# Mileage               int32
# Cylinders           float64
# Airbags               int64
# Age                   int64
# dtype: object

# %%
#///////////////////////////////////modeling////////////////////////////

# %%
x = df.drop('Price',axis=1)
y = df['Price']

# %%
x
# Out:
#        Manufacturer  Model  Category  Leather interior  Fuel type  \
# 0                32   1242         4                 1          2
# 1                 8    658         4                 0          5
# 2                21    684         3                 0          5
# 3                16    661         4                 1          2
# 4                21    684         3                 1          5
# ...             ...    ...       ...               ...        ...
# 19232            36    385         1                 1          0
# 19233            23   1334         9                 1          5
# 19234            23   1442         4                 1          1
# 19235             8    456         4                 1          1
# 19236            23   1334         9                 1          2
#
#        Gear box type  Drive wheels  Wheel  Color  Levy  Engine volume  \
# 0                  0             0      0     12  1399            3.5
# ...

# %%
y
# Out:
# 0        13328
# 1        16621
# 2         8467
# 3         3607
# 4        11726
#          ...
# 19232     8467
# 19233    15681
# 19234    26108
# 19235     5331
# 19236      470
# Name: Price, Length: 18924, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR

from sklearn.metrics import r2_score,mean_squared_error

# %%
Algorithm =['LinearRegression','DecisionTreeRegressor','RandomForestRegressor','GradientBoostingRegressor','XGBRegressor','SVR']
R2=[]
RMSE=[]

# %%
import numpy as np

# %%
def models(model):
    model.fit(x_train,y_train)    # y_train لما المودل بتاعي يتدرب النتيجه بتاعتي بتبقي في ال 
    predict = model.predict(x_test)    # y_test بقول للمودل يتوقع ال 
    r2=r2_score(y_test,predict)  #  و التوقع y_testبيقيس مدي الكفاءه مع النتيجه الحقيقه اللي هي 
    rmse=np.sqrt(mean_squared_error(y_test,predict))    # دا الجذر بتاع الداتا
    R2.append(r2)       # list يعني ضيف عنصر في اخر ال 
    RMSE.append(rmse)             
    score=model.score(x_test,y_test)     #نتيجه التوقع بتاعك
    print(f"The Score of Model is : {score}")   #  دا بناع النص format يعني f ------- دي الجمله اللي هيطبعها وبعدين جنبها النتيجه

# %%
model1=LinearRegression()
model2=DecisionTreeRegressor()
model3=RandomForestRegressor()
model4=GradientBoostingRegressor()
model5=XGBRegressor()
model6=SVR()

# %%
models(model1)
models(model2)
models(model3)
models(model4)
models(model5)
models(model6)
# Out:
# The Score of Model is : 0.02521905777536637
# The Score of Model is : 0.38134514478356163
# The Score of Model is : -0.3777219326803989
# The Score of Model is : -92.97750619469834
# The Score of Model is : 0.6308581829071045
# The Score of Model is : -0.04812902037133182

# %%
df=pd.DataFrame({'Algorithm':Algorithm,'R2_Score':R2,'RMSE':RMSE})
df
# Out:
#                    Algorithm   R2_Score           RMSE
# 0           LinearRegression   0.025219   18371.082128
# 1      DecisionTreeRegressor   0.381345   14635.428306
# 2      RandomForestRegressor  -0.377722   21840.471503
# 3  GradientBoostingRegressor -92.977506  180381.993377
# 4               XGBRegressor   0.630858   11305.189809
# 5                        SVR  -0.048129   19049.720002

# %%
fig,sx=plt.subplots(figsize=(20,5))
plt.plot(df.Algorithm,df.R2_Score,label='R2_Score',marker='o')
plt.legend()
plt.show()

# %%
fig,sx=plt.subplots(figsize=(20,5))
plt.plot(df.Algorithm,df.RMSE,label='RMSE',marker='o')
plt.legend()
plt.show()

# %%
#----------------------------------
